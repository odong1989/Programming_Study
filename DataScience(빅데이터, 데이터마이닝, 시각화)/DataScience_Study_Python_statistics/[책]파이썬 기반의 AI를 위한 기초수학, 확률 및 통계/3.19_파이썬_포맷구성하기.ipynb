# %%
#"포맷을 구성한다" ="아무 데이터 형이나 또는 특별한 형식으로 문자열 만들어 주는 것."
#형식 : 포맷지시문.format(포맷할 값)

# %%
#소수점 이하 2번째 자리까지
"${:.2f}".format(12345.12345)
# Out:
# '$12345.12'

# %%
#콤마 포맷
"{:,}원".format(1234567890)
# Out:
# '1,234,567,890원'

# %%
#콤마 포맷과 소수점 이하 1째 자리까지
"{:,.1f}원".format(12345.77)
# Out:
# '12,345.8원'

# %%
#포맷할 값의 2번째 인자에 대한 포맷 지정 : 오른쪽 정렬까지 지정(>)
"{1:>20s}".format(12345, 'bong ju kang')
# Out:
# '        bong ju kang'

# %%
#포맷할 값의 2번째 인자에 대한 포맷 지정 : 가운데 정렬까지 지정(^)
"{1:^20s}".format(12345,'bong ju kang')
# Out:
# '    bong ju kang    '
