# %%
logistic_reg = sm.Logit(y,x).fit()
logistic_reg.summary()
logistic_reg_pred = logistic_reg.predict(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fd87a0f4768b> in <module>()
# ----> 1 logistic_reg = sm.Logit(y,x).fit()
#       2 logistic_reg.summary()
#       3 logistic_reg_pred = logistic_reg.predict(x)
#
# NameError: name 'sm' is not defined
