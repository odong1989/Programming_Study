# %%
import numpy as np

p=3
n=5

#initial beta
beta = np.zeros((p,1))
for i in range(n) :
  #모수추정값 1차 미분 계산
  parm = np.exp(x @ beta)
  grad = -np.mean(y*x - parm*x, axis=0).reshape((p,1))

  #beta update
  beta_new = beta - 0.5*grad

  #stopping rule
  if np.sum(np.abs(beta_new - beta)) < 1e-8:
    beta = beta_new
    print('Iteration {} beta :'.format(i+1))
    print(beta, '\n')
    break
  else:
    beta = beta_new
    print('Iteration {} beta : '.format(i+1))
    print(beta, '\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-77413e72de23> in <module>()
#       8 for i in range(n) :
#       9   #모수추정값 1차 미분 계산
# ---> 10   parm = np.exp(x @ beta)
#      11   grad = -np.mean(y*x - parm*x, axis=0).reshape((p,1))
#      12
#
# NameError: name 'x' is not defined
