# %%
pi0 = 2000 / 5000
pi1 = 3000 / 5000

def bayes_prob(x,y):
  if y == 1 : 
    return f_x_y1(x)*p1 / (f_x_y0(x) * p0 + f_x_y1(x)*p1)
#  else :
#    return
sample_x=1

bayes_prob(sample_x, 0)
bayes_prob(sample_x, 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-eec63b5771f7> in <module>()
#      10
#      11 bayes_prob(sample_x, 0)
# ---> 12 bayes_prob(sample_x, 1)
#
# <ipython-input-2-eec63b5771f7> in bayes_prob(x, y)
#       4 def bayes_prob(x,y):
#       5   if y == 1 :
# ----> 6     return f_x_y1(x)*p1 / (f_x_y0(x) * p0 + f_x_y1(x)*p1)
#       7 #  else :
#       8 #    return
#
# NameError: name 'f_x_y1' is not defined
