# %%
#파이썬의 형 변황 함수는 아래와 같다.
#①int() 
#②float()
#③bool()
#④str()
#⑤chr()
#⑥bytes()
#⑦list()
#⑧dict()
#⑨set()
#

# %%
#①int()
#문자열에서 정수로
[int("100"),ord('\n')]
# Out:
# [100, 10]

# %%
#①int() 
#②float()
#③bool()
#④str()
#⑤chr()
#⑥bytes()
#⑦list()
#⑧dict()
#⑨set()

# %%
#①int() 
#②float()
#③bool()
#④str()
#⑤chr()
#⑥bytes()
#⑦list()
#⑧dict()
#⑨set()

# %%
#①int() 
#②float()
#③bool()
#④str()
#⑤chr()
#⑥bytes()
#⑦list()
#⑧dict()
#⑨set()

# %%
#①int() 
#②float()
#③bool()
#④str()
#⑤chr()
#⑥bytes()
#⑦list()
#⑧dict()
#⑨set()

# %%
#①int() 
#②float()
#③bool()
#④str()
#⑤chr()
#⑥bytes()
#⑦list()
#⑧dict()
#⑨set()

# %%
#①int() 
#②float()
#③bool()
#④str()
#⑤chr()
#⑥bytes()
#⑦list()
#⑧dict()
#⑨set()
