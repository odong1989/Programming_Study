# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import numpy as np
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\tf_2_3\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
learning_rate=0.1
tf.set_random_seed(0)
np.random.seed(0)

# %%
x_data=[[0,0], [0,1], [1,0], [1,1] ]
y_data=[[0], [1], [1], [0] ]

# %%
X = tf.placeholder(tf.float32, [None, 2])
Y = tf.placeholder(tf.float32, [None, 1])

# %%
W1 = tf.Variable(tf.random_normal([2,5], name='weight1'))//보내는쪽(입력층x1,x2) 기준 
b1 = tf.Variable(tf.random_normal([5]),name='bias1' )

# %%
layer1 = tf.sigmoid(tf.matmul(X,W1) +b1)

# %%
W2 = tf.Variable(tf.random_normal([5,1], name='weight2'))//받는쪽(출력y)
b2 = tf.Variable(tf.random_normal([1]),name='bias2' )

# %%
hypothesis = tf.sigmoid(tf.matmul(layer1, W2) +b2)

# %%
cost = -tf.reduce_mean(Y * tf.log(hypothesis) + (1-Y) * tf.log(1-hypothesis) )
train = tf.train.GradientDescentOptimizer(learning_rate).minimize(cost)

predicted = tf.cast(hypothesis > 0.5, dtype=tf.float32 )
accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, Y), dtype=tf.float32 ))

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for step in range(10001):
        sess.run(train, feed_dict={X: x_data, Y:y_data})
        if step % 100 == 0:
            print(step, sess.run(cost, feed_dict={X: x_data, Y:y_data }) , sess.run(W2) )
            
    h,c,a = sess.run([hypothesis, predicted, accuracy], feed_dict={X:x_data, Y:y_data})
    print("\n Hypothesis: \n", h, "\nCorrect : \n", c, "\nAccuracy : \n", a )
# Out:
# 0 0.9456148 [[ 0.10782848]
#  [ 0.75730467]
#  [ 0.29221863]
#  [-1.5880265 ]
#  [ 1.8650784 ]]
# 100 0.68173796 [[ 0.37353104]
#  [ 1.2683687 ]
#  [ 0.08135341]
#  [-1.2598025 ]
#  [ 1.8891948 ]]
# 200 0.6649838 [[ 0.34210876]
#  [ 1.4137251 ]
#  [-0.15637913]
#  [-1.3035946 ]
#  [ 1.8272753 ]]
# 300 0.6499058 [[ 0.31049156]
#  [ 1.5771681 ]
#  [-0.37031063]
#  [-1.3469033 ]
#  [ 1.7925613 ]]
# 400 0.63456357 [[ 0.27796263]
#  [ 1.7565567 ]
#  [-0.5656774 ]
#  [-1.3913763 ]
#  [ 1.7759027 ]]
# 500 0.6184837 [[ 0.24416883]
#  [ 1.9475775 ]
#  [-0.7447382 ]
#  [-1.4388856 ]
#  [ 1.7742062 ]]
# 600 0.601874 [[ 0.20925838]
#  [ 2.1445048 ]
#  [-0.908328  ]
#  [-1.4910419 ]
#  [ 1.7868435 ]]
# 700 0.58515817 [[ 0.17367284]
#  [ 2.34135   ]
#  [-1.0570645 ]
#  [-1.5491312 ]
#  [ 1.813936  ]]
# 800 0.568672 [[ 0.13790303]
#  [ 2.5331485 ]
#  [-1.1920345 ]
#  [-1.6140634 ]
#  [ 1.8556327 ]]
# 900 0.5525268 [[ 0.10224072]
#  [ 2.7166367 ]
#  [-1.3149415 ]
#  [-1.686398  ]
#  [ 1.9120083 ]]
# ...
